# %%
import numpy as np
import pandas as pd


df = pd.read_csv("perfume_cleaned.csv")
df
# Out:
#        Unnamed: 0                        brand  \
# 0               0          The-Spirit-of-Dubai
# 1               1                        Ajmal
# 2               2          Al-Jazeera-Perfumes
# 3               3  Art-of-Scent-Swiss-Perfumes
# 4               4          Hamidi-Oud-Perfumes
# ...           ...                          ...
# 51207       51207  Maitre-Parfumeur-et-Gantier
# 51208       51208                    Como-Lake
# 51209       51209                   Battistoni
# 51210       51210       12-Parfumeurs-Francais
# 51211       51211                   OPSObjects
#
#                                                    title  date  \
# 0            Aamal The Spirit of Dubai for women and men  2017
# 1                         Aatifa Ajmal for women and men  2014
# 2               AA Al-Jazeera Perfumes for women and men     0
# 3      aarewasser Art of Scent - Swiss Perfumes for w...  2010
# 4        Aaliyah Hamidi Oud & Perfumes for women and men     0
# ...

# %%
# Shape of our dataset
df.shape

# Info our dataset
df.info()

# Describe our dataset
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51212 entries, 0 to 51211
# Data columns (total 87 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                51212 non-null  int64
#  1   brand                     51212 non-null  object
#  2   title                     51212 non-null  object
#  3   date                      51212 non-null  int64
#  4   accords                   50268 non-null  object
#  5   rating_score              51212 non-null  float64
#  6   votes                     51212 non-null  int64
#  7   longevity_poor            51212 non-null  int64
#  8   longevity_weak            51212 non-null  int64
#  9   longevity_moderate        51212 non-null  int64
#  10  longevity_long            51212 non-null  int64
#  11  longevity_very_long       51212 non-null  int64
#  12  sillage_soft              51212 non-null  int64
#  13  sillage_moderate          51212 non-null  int64
# ...

# %%
# I can't figure out why the visualization won't show
import matplotlib.pyplot as plt 
import seaborn as sns


sns.pairplot(df, x_vars=['longevity_very_long', 'longevity_long', 'clssummer', 'clsspring', 'clsnight'], 
             y_vars='Iwantit', height=6, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

#I'm not sure how to fix this

# %%
X = df['longevity_very_long']
y = df['Iwantit']

# %%
# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
X_train
# Out:
# 1527     1
# 9128     6
# 30979    3
# 30410    0
# 13383    0
#         ..
# 16304    0
# 79       1
# 12119    1
# 14147    0
# 38408    0
# Name: longevity_very_long, Length: 35848, dtype: int64

# %%
y_train
# Out:
# 1527     0
# 9128     0
# 30979    0
# 30410    0
# 13383    0
#         ..
# 16304    0
# 79       0
# 12119    0
# 14147    0
# 38408    2
# Name: Iwantit, Length: 35848, dtype: int64

# %%
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train)

# %%
lr = sm.OLS(y_train, X_train_sm).fit()

lr.params
# Out:
# const                  0.500335
# longevity_very_long   -0.002853
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Iwantit   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     43.14
# Date:                Thu, 10 Mar 2022   Prob (F-statistic):           5.18e-11
# Time:                        20:55:10   Log-Likelihood:                -75386.
# No. Observations:               35848   AIC:                         1.508e+05
# Df Residuals:                   35846   BIC:                         1.508e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...
